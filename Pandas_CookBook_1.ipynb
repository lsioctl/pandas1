# %% [markdown]
# # Read from CSV
#
# from: https://tutswiki.com/pandas-cookbook/chapter1/

# %%
import pandas as pd

# %%
broken_df = pd.read_csv('bikes.csv')

# %%
broken_df
# Out:
#     Date;Berri 1;Br?beuf (donn?es non disponibles);C?te-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (donn?es non disponibles)
# 0                     01/01/2012;35;;0;38;51;26;10;16;
# 1                     02/01/2012;83;;1;68;153;53;6;43;
# 2                   03/01/2012;135;;2;104;248;89;3;58;
# 3                  04/01/2012;144;;1;116;318;111;8;61;
# 4                  05/01/2012;197;;2;124;330;97;13;95;
# ..                                                 ...
# 305      01/11/2012;2405;;1208;1701;3082;2076;165;2461
# 306        02/11/2012;1582;;737;1109;2277;1392;97;1888
# 307          03/11/2012;844;;380;612;1137;713;105;1302
# 308          04/11/2012;966;;446;710;1277;692;197;1374
# 309      05/11/2012;2247;;1170;1705;3221;2143;179;2430
#
# [310 rows x 1 columns]

# %%
df = pd.read_csv(
    'bikes.csv',
    # Note: the encoding is not anymore latin1, we have real ? in ASCII
    encoding='latin1',
    sep=';',
    parse_dates=['Date'],
    # the date in the csv has day first and not the month first
    dayfirst=True,
    index_col=['Date']
)

# %%
df
# Out:
#             Berri 1  Br?beuf (donn?es non disponibles)  C?te-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
# 2012-01-04      144                                NaN                      1
# 2012-01-05      197                                NaN                      2
# ...             ...                                ...                    ...
# 2012-11-01     2405                                NaN                   1208
# 2012-11-02     1582                                NaN                    737
# 2012-11-03      844                                NaN                    380
# 2012-11-04      966                                NaN                    446
# 2012-11-05     2247                                NaN                   1170
#
# ...

# %% [markdown]
# # Selecting a column

# %%
df['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
#               ...
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310, dtype: int64

# %% [markdown]
# # Ploting a column

# %%
df['Berri 1'].plot()

# %%
#Seems we have to import matplot lib first
import matplotlib as plt

# %%
df['Berri 1'].plot()

# %%
# change the style
# deprecated
#pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
df['Berri 1'].plot()

# %%
df.plot(figsize=(15, 10))

# %%
# Jupyter instruction
# does not seem to be needed. Set the matplotlib backend to this page
# see: https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline
# %matplotlib inline

# %%
# anoth Jupyter instruction to measure time
# %time
df.plot(figsize=(15, 10))
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.82 µs
