# %% [markdown]
# # Selecting and finding data
#
# from: https://tutswiki.com/pandas-cookbook/chapter2/

# %%
# The usual preamble
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 5)

# %%
complaints = pd.read_csv('311-service-requests.csv')
# Out:
# /home/lswork/miniconda3/envs/bc2019/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
complaints
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1         26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2         26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3         26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4         26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# ...            ...                     ...                     ...    ...
# 111064    26426013  10/04/2013 12:01:13 AM  10/07/2013 04:07:16 PM    DPR
# 111065    26428083  10/04/2013 12:01:05 AM  10/04/2013 02:13:50 AM   NYPD
# 111066    26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067    26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
# 111068    26428033  10/04/2013 12:00:10 AM  10/04/2013 01:20:52 AM   NYPD
#
#                                     Agency Name           Complaint Type  \
# ...

# %%
complaints.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                       object
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Action Updated Date     object
# ...

# %%
complaints.ftypes
# Out:
# /home/lswork/miniconda3/envs/bc2019/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.ftypes is deprecated and will be removed in a future version. Use DataFrame.dtypes instead.
#   """Entry point for launching an IPython kernel.
# Unique Key                          int64:dense
# Created Date                       object:dense
# Closed Date                        object:dense
# Agency                             object:dense
# Agency Name                        object:dense
# Complaint Type                     object:dense
# Descriptor                         object:dense
# Location Type                      object:dense
# Incident Zip                       object:dense
# Incident Address                   object:dense
# Street Name                        object:dense
# Cross Street 1                     object:dense
# Cross Street 2                     object:dense
# Intersection Street 1              object:dense
# ...

# %%
# Get the first 5 rows
complaints[:5]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# ...

# %%
# it can be combined with one column
complaints['Agency'][:5]
# Out:
# 0     NYPD
# 1     NYPD
# 2     NYPD
# 3     NYPD
# 4    DOHMH
# Name: Agency, dtype: object

# %%
# multiple columns
complaints[['Agency', 'Descriptor']]
# Out:
#        Agency                     Descriptor
# 0        NYPD                   Loud Talking
# 1        NYPD   Commercial Overnight Parking
# 2        NYPD               Loud Music/Party
# 3        NYPD                 Car/Truck Horn
# 4       DOHMH   Condition Attracting Rodents
# ...       ...                            ...
# 111064    DPR           Structure - Outdoors
# 111065   NYPD  Posted Parking Sign Violation
# 111066   NYPD                   Loud Talking
# 111067   NYPD                   Loud Talking
# 111068   NYPD                 Partial Access
#
# [111069 rows x 2 columns]

# %%
complaints.describe()
# Out:
#          Unique Key  X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# count  1.110690e+05                9.814300e+04                98143.000000
# mean   2.651565e+07                1.004544e+06               205553.153287
# std    4.694558e+04                2.206087e+04                31334.677543
# min    2.642588e+07                9.134950e+05               121152.000000
# 25%    2.647433e+07                9.920490e+05               182506.000000
# 50%    2.651472e+07                1.003205e+06               203251.000000
# 75%    2.655684e+07                1.016823e+06               233366.000000
# max    2.659613e+07                1.067024e+06               271485.000000
#
#        School or Citywide Complaint      Latitude     Longitude
# count                           0.0  98143.000000  98143.000000
# mean                            NaN     40.730821    -73.926738
# std                             NaN      0.086006      0.079563
# ...

# %%
# Most common complaint type
complaints['Complaint Type'].value_counts()
# Out:
# HEATING                           14200
# GENERAL CONSTRUCTION               7471
# Street Light Condition             7117
# DOF Literature Request             5797
# PLUMBING                           5373
#                                   ...
# Ferry Permit                          1
# Municipal Parking Facility            1
# Open Flame Permit                     1
# Trans Fat                             1
# DHS Income Savings Requirement        1
# Name: Complaint Type, Length: 165, dtype: int64

# %%
# Top 10 complaints type
complaints_type = complaints['Complaint Type'].value_counts()
complaints_type[:10]
# Out:
# HEATING                   14200
# GENERAL CONSTRUCTION       7471
# Street Light Condition     7117
# DOF Literature Request     5797
# PLUMBING                   5373
# PAINT - PLASTER            5149
# Blocked Driveway           4590
# NONCONST                   3998
# Street Condition           3473
# Illegal Parking            3343
# Name: Complaint Type, dtype: int64

# %%
complaints_type[:10].plot(kind='bar')
